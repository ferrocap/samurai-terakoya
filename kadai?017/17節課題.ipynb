# %%
class Human:
    def __init__(self, name, age):
        self.name = name
        self.age = age
        self.adult_check = age - 20

    # メソッドを定義する
    def set_age(self, age):
        self.age = age
        self.adult_check = age - 20

    def set_adult_check(self):
        if self.adult_check >= 0:
            return("大人である")
        else:
            return("大人でない")

# クラスの外でHumanのインスタンスを作成する
human1 = Human("侍太郎", 36)
human2 = Human("侍次郎", 30)
human3 = Human("侍三郎", 25)
human4 = Human("侍四郎", 20)
human5 = Human("侍五郎", 17)

humans = [human1]
humans.append(human2)
humans.append(human3)
humans.append(human4)
humans.append(human5)

humans_adult_check = [human1.set_adult_check()]
humans_adult_check.append(human2.set_adult_check())
humans_adult_check.append(human3.set_adult_check())
humans_adult_check.append(human4.set_adult_check())
humans_adult_check.append(human5.set_adult_check())
# 'set_adult_checkadult_check'を'adult_check'に修正
print(humans_adult_check)
# Out:
# ['大人である', '大人である', '大人である', '大人である', '大人でない']
