# %%
var=21
if var % 3==0 and var % 5==0:
    print("FizzBuzz")
elif var % 3==0 and var % 5>0:
    print("Fizz")
elif var % 3> 0 and var % 5==0:
  print("Buzz")
elif var % 3>0 and var % 5>0:
  print(var)
# Out:
# Fizz
