# %%
class Human:
    def __init__(self, name, age):
        self.name = name
        self.age = age
        self.adult_check = age - 20

    # メソッドを定義する
    def set_age(self, age):
        self.age = age
        self.adult_check = age - 20

    def set_adult_check(self):
        if self.adult_check >= 0:
            return("大人である")
        else:
            return("大人でない")

# クラスの外でHumanのインスタンスを作成する
human1 = Human("侍太郎", 36)
human2 = Human("侍次郎", 30)
human3 = Human("侍三郎", 25)
human4 = Human("侍四郎", 20)
human5 = Human("侍五郎", 17)

# for ループでリストを作成する方法①　リストの要素を取得
humans_adult_check= [] # 空のリストを初期化

for human in humans:
    humans_adult_check.append(human.set_adult_check())

print(humans_adult_check)
# Out:
# ['大人である', '大人である', '大人である', '大人である', '大人でない']
