# %%
class Human:
    # コンストラクタを定義する
    def __init__(self, name, age):
        self.name = "侍太郎"
        self.age = 36

    def printinfo(self, name, age)
        printinfo.name = print(name)

    def printinfo(self, name, age)
         printinfo.age =print(age)
# インスタンス化する
user = Human()

shampoo._name("シャンプー")
# 属性にアクセスし、値を出力する
print(user.name)
print(user.age)
# Out:
#   File "/tmp/ipython-input-536953745.py", line 8
#     self.name = print(name)
#     ^
# IndentationError: unexpected indent

# %%
class Human:
    # コンストラクタを定義する
    def __init__(self, name, age):
        self.name = name
        self.age = age

    # 自身の名前と年齢を出力するメソッド
    def printinfo(self):
        print(f"名前: {self.name}")
        print(f"年齢: {self.age}")

# インスタンス化する際に、nameとageの引数を渡す
user = Human("侍太郎", 36)

# printinfoメソッドを呼び出して情報を出力する
user.printinfo()
# Out:
# 名前: 侍太郎
# 年齢: 36
